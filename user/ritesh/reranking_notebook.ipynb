# %%
import os
import random
import pyarrow.parquet as pq
import pandas as pd

from datasets import load_dataset

# %%
# Load Wikipedia English embeddings (streaming avoids loading all into memory)
dataset = load_dataset("Upstash/wikipedia-2024-06-bge-m3", "en", split="train")
# Out:
# ...
# Resolving data files:   0%|          | 0/471 [00:00<?, ?it/s]
# ...
# 000.parquet:   0%|          | 0.00/444M [00:00<?, ?B/s]
# 001.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 002.parquet:   0%|          | 0.00/444M [00:00<?, ?B/s]
# 003.parquet:   0%|          | 0.00/445M [00:00<?, ?B/s]
# 004.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 005.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 006.parquet:   0%|          | 0.00/446M [00:00<?, ?B/s]
# 007.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 008.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 009.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# 010.parquet:   0%|          | 0.00/442M [00:00<?, ?B/s]
# 011.parquet:   0%|          | 0.00/442M [00:00<?, ?B/s]
# 012.parquet:   0%|          | 0.00/442M [00:00<?, ?B/s]
# 013.parquet:   0%|          | 0.00/438M [00:00<?, ?B/s]
# 014.parquet:   0%|          | 0.00/437M [00:00<?, ?B/s]
# 015.parquet:   0%|          | 0.00/432M [00:00<?, ?B/s]
# ...

# %%
import os
import random
import pyarrow.parquet as pq
import pandas as pd

from datasets import load_dataset

# %%
import os
import random
import pyarrow.parquet as pq
import pandas as pd

from datasets import load_dataset

# %%
corpus_parquet_path = "/workspace/split_parquet_shards"

# %%
# lets pick a random shard fromt he corpus_parquet_path and open the parquet file
shard_file = random.choice(os.listdir(corpus_parquet_path))
shard_path = os.path.join(corpus_parquet_path, shard_file)
df_shard = pd.read_parquet(shard_path)

# lets pick a random id from the "id" column
target_doc_id = df_shard["id"].sample(1).values[0]

# Find and print all embeddings matching the doc_id
for item in dataset:
    print(f"item id: {item['id']}, title: {item['title']}")
    if item["id"] == target_doc_id:
        print("Title:", item["title"])
        print("Embedding:", item["embedding"])
        print("Text:", item["text"])
        # If you only want the first match (e.g., first paragraph), use break
        # break
# Out:
# item id: 12_0, title: Anarchism
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 12
#      10 for item in dataset:
#      11     print(f"item id: {item['id']}, title: {item['title']}")
# ---> 12     if item["id"] == target_doc_id:
#      13         print("Title:", item["title"])
#      14         print("Embedding:", item["embedding"])
#
# Cell In[11], line 12
#      10 for item in dataset:
#      11     print(f"item id: {item['id']}, title: {item['title']}")
# ---> 12     if item["id"] == target_doc_id:
#      13         print("Title:", item["title"])
#      14         print("Embedding:", item["embedding"])
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# ...
